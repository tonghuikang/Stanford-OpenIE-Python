# %%
# !echo "Dissent is banned by the Singapore government. Singapore bans dissent." > samples.txt
# !python main.py -f samples.txt -o out2.txt -g
# Out:
# Namespace(filename='samples.txt', generate_graph=True, output='out2.txt', verbose=False)
# Wrote graph to /tmp/openie/out.dot and /tmp/openie/out.png
# [['Dissent', ' is', ' banned'], ['Dissent', ' is banned by', ' Singapore government'], ['Singapore', ' bans', ' dissent']]

# %%
import pickle
with open("out2.txt", "rb") as fp:   # Unpickling
    b = pickle.load(fp)
    print(b)
# Out:
# [['Dissent', ' is', ' banned'], ['Dissent', ' is banned by', ' Singapore government'], ['Singapore', ' bans', ' dissent']]

# %%
from IPython.display import Image
Image("/tmp/openie/out.png")
